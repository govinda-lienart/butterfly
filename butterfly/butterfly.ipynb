# %% [markdown]
# # BUTTERFLY

# %% [markdown]
# ![Lime-butterfly-Papilio-demoleus-feeding-on-flower.webp](data:image/webp;base64,...)

# %% [markdown]
# Task 1: Data Cleaning and Preparation
#
# 	1.	Load the Butterfly Observations (Extended) dataset.
# 	2.	Convert the date_observed column to datetime format.
# 	3.	Verify if there are any missing values and handle them if found.
#
# Task 2: Data Merging
#
# 	1.	Merge the Butterfly Observations (Extended) dataset with the Species Details dataset using the species column.
# 	2.	Merge the resulting dataset with Observer Contributions using the observer column.
# 	3.	Display the first 10 rows of the final dataset.
#
# Task 3: Trend Analysis
#
# 	1.	Group the observations by year and count the number of observations each year.
# 	2.	Plot a bar chart showing the number of butterfly observations per year.
# 	3.	Analyze if any specific year had a significant increase or decrease in observations.
#
# Task 4: Observer Analysis
#
# 	1.	Create a histogram to show the distribution of the number of observations made by each observer.
# 	2.	Identify the top contributor based on the total number of observations.
# 	3.	Filter the dataset to show only observations made by the top contributor and analyze their preferred locations.
#
# Task 5: Species and Habitat Analysis
#
# 	1.	Identify which species have been observed in the most diverse habitats.
# 	2.	Group the data by species and count the number of unique habitats for each species.
# 	3.	Plot a bar chart showing the number of unique habitats for each species.
#
# Task 6: Hotspots of Observation
#
# 	1.	Determine the top 3 most frequently observed locations.
# 	2.	Filter the dataset to include only observations from these locations.
# 	3.	Analyze the species diversity in these locations.
#
# Task 7: Recent Activity
#
# 	1.	Identify the last 10 observations recorded in the dataset.
# 	2.	Analyze which species were observed and where.
# 	3.	Plot the observation dates for these records to see if they cluster around specific periods.
#
# Task 8: Comparing Observers
#
# 	1.	Select two observers (e.g., Alice and Bob).
# 	2.	Compare their observation patterns by year. Plot their contributions side by side.
# 	3.	Identify who observed more diverse species.
#
# Task 9: Species Wingspan Analysis
#
# 	1.	Calculate the average observed wingspan for each species using the Species Details dataset.
# 	2.	Plot a bar chart showing the average wingspan for each species.
# 	3.	Compare these averages with the provided wingspan range to check for consistency.
#
# Task 10: Exploration Challenge
#
# 	1.	Identify if there is a correlation between the number of observations and the number of habitats for each species.
# 	2.	Use scatter plots to visualize this relationship.
# 	3.	Provide a brief analysis based on the findings.

# %% [markdown]
# ##Task 1: Data Cleaning and Preparation

# %% [markdown]
# ###	1.	Load the Butterfly Observations (Extended) dataset.
#
# *   List item
# *   List item

# %%
import  pandas as pd
path = 'https://drive.google.com/open?id=1utAZxFeMZ9_XVNtfA89Kwoz2tof66XZR&usp=drive_fs'

# %%
df_butterfly_obs = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-14-eb11eb24e626> in <cell line: 1>()
# ----> 1 df_butterfly_obs = pd.read_csv(path)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...
